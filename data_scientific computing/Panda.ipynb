# %%
import pandas as pd
data = pd.read_csv('assignment.csv')
data
# Out:
#      Age  Gender Smoking Status  Lung Capacity Disease Type Treatment Type  \
# 0   71.0  Female             No           4.49         COPD        Therapy
# 1   34.0  Female            Yes            NaN   Bronchitis        Surgery
# 2   80.0    Male            Yes           1.95         COPD            NaN
# 3   40.0  Female            Yes            NaN   Bronchitis     Medication
# 4   43.0    Male            Yes           4.60         COPD        Surgery
# ..   ...     ...            ...            ...          ...            ...
# 94  63.0  Female             No           3.47   Bronchitis     Medication
# 95  54.0    Male            Yes           2.03  Lung Cancer            NaN
# 96  84.0    Male             No           4.69  Lung Cancer     Medication
# 97  66.0    Male            Yes           4.50   Bronchitis     Medication
# 98  22.0  Female             No           2.23         COPD        Surgery
#
#     Hospital Visits Recovered
# 0              14.0       Yes
# ...

# %%
data.describe()
# Out:
#              Age  Lung Capacity  Hospital Visits
# count  95.000000      95.000000        94.000000
# mean   53.294737       3.357684         7.755319
# std    21.060639       1.409369         3.840044
# min    20.000000       1.100000         1.000000
# 25%    34.000000       2.160000         5.000000
# 50%    54.000000       3.300000         8.000000
# 75%    72.000000       4.545000        11.000000
# max    84.000000       5.940000        14.000000

# %%
data.dtypes
# Out:
# Age                float64
# Gender              object
# Smoking Status      object
# Lung Capacity      float64
# Disease Type        object
# Treatment Type      object
# Hospital Visits    float64
# Recovered           object
# dtype: object

# %%
data.head(10)
# Out:
#     Age  Gender Smoking Status  Lung Capacity Disease Type Treatment Type  \
# 0  71.0  Female             No           4.49         COPD        Therapy
# 1  34.0  Female            Yes            NaN   Bronchitis        Surgery
# 2  80.0    Male            Yes           1.95         COPD            NaN
# 3  40.0  Female            Yes            NaN   Bronchitis     Medication
# 4  43.0    Male            Yes           4.60         COPD        Surgery
# 5  22.0  Female             No           3.65   Bronchitis     Medication
# 6  41.0    Male            Yes           2.98       Asthma     Medication
# 7  72.0    Male            NaN           2.61  Lung Cancer        Surgery
# 8  21.0  Female             No           4.05  Lung Cancer     Medication
# 9  49.0    Male            Yes           5.70    Pneumonia     Medication
#
#    Hospital Visits Recovered
# 0             14.0       Yes
# 1              7.0        No
# 2              4.0       Yes
# 3              1.0        No
# ...

# %%
data.tail(10)
# Out:
#      Age  Gender Smoking Status  Lung Capacity Disease Type Treatment Type  \
# 89  52.0     NaN             No           1.85       Asthma     Medication
# 90  67.0    Male            Yes           1.22   Bronchitis     Medication
# 91  42.0  Female             No           4.27  Lung Cancer     Medication
# 92  81.0  Female             No           4.87    Pneumonia        Therapy
# 93  56.0    Male            Yes           5.07         COPD     Medication
# 94  63.0  Female             No           3.47   Bronchitis     Medication
# 95  54.0    Male            Yes           2.03  Lung Cancer            NaN
# 96  84.0    Male             No           4.69  Lung Cancer     Medication
# 97  66.0    Male            Yes           4.50   Bronchitis     Medication
# 98  22.0  Female             No           2.23         COPD        Surgery
#
#     Hospital Visits Recovered
# 89              9.0       Yes
# 90             12.0        No
# 91             11.0        No
# ...

# %%
data.shape
# Out:
# (99, 8)

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Smoking Status', 'Lung Capacity', 'Disease Type',
#        'Treatment Type', 'Hospital Visits', 'Recovered'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Age                4
# Gender             7
# Smoking Status     3
# Lung Capacity      4
# Disease Type       7
# Treatment Type     8
# Hospital Visits    5
# Recovered          5
# dtype: int64

# %%
data
# Out:
#      Age  Gender Smoking Status  Lung Capacity Disease Type Treatment Type  \
# 0   71.0  Female             No           4.49         COPD        Therapy
# 1   34.0  Female            Yes            NaN   Bronchitis        Surgery
# 2   80.0    Male            Yes           1.95         COPD            NaN
# 3   40.0  Female            Yes            NaN   Bronchitis     Medication
# 4   43.0    Male            Yes           4.60         COPD        Surgery
# ..   ...     ...            ...            ...          ...            ...
# 94  63.0  Female             No           3.47   Bronchitis     Medication
# 95  54.0    Male            Yes           2.03  Lung Cancer            NaN
# 96  84.0    Male             No           4.69  Lung Cancer     Medication
# 97  66.0    Male            Yes           4.50   Bronchitis     Medication
# 98  22.0  Female             No           2.23         COPD        Surgery
#
#     Hospital Visits Recovered
# 0              14.0       Yes
# ...

# %%
sampleData=data.sample(30)
sampleData
# Out:
#      Age  Gender Smoking Status  Lung Capacity Disease Type Treatment Type  \
# 7   72.0    Male            NaN           2.61  Lung Cancer        Surgery
# 96  84.0    Male             No           4.69  Lung Cancer     Medication
# 0   71.0  Female             No           4.49         COPD        Therapy
# 1   34.0  Female            Yes            NaN   Bronchitis        Surgery
# 40  72.0  Female            Yes           4.19    Pneumonia            NaN
# 55  82.0  Female            Yes           3.48         COPD     Medication
# 21  79.0    Male            Yes           3.09          NaN        Therapy
# 73  84.0  Female            Yes           1.90       Asthma     Medication
# 59  81.0  Female            Yes           1.31         COPD        Surgery
# 89  52.0     NaN             No           1.85       Asthma     Medication
# 84  60.0     NaN             No           2.72  Lung Cancer        Surgery
# ...

# %%
sampleData["Age"].fillna(sampleData["Age"].mean(), inplace=True)
sampleData["Lung Capacity"].fillna(sampleData["Lung Capacity"].mean(), inplace=True)
sampleData["Hospital Visits"].fillna(sampleData["Hospital Visits"].mean(), inplace=True)
sampleData.fillna(method='bfill', inplace=True)
sampleData
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16800\1109373798.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sampleData["Age"].fillna(sampleData["Age"].mean(), inplace=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_16800\1109373798.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
sampleData.isna().sum()
# Out:
# Age                0
# Gender             0
# Smoking Status     0
# Lung Capacity      0
# Disease Type       0
# Treatment Type     0
# Hospital Visits    0
# Recovered          0
# dtype: int64

# %%
data
# Out:
#      Age  Gender Smoking Status  Lung Capacity Disease Type Treatment Type  \
# 0   71.0  Female             No           4.49         COPD        Therapy
# 1   34.0  Female            Yes            NaN   Bronchitis        Surgery
# 2   80.0    Male            Yes           1.95         COPD            NaN
# 3   40.0  Female            Yes            NaN   Bronchitis     Medication
# 4   43.0    Male            Yes           4.60         COPD        Surgery
# ..   ...     ...            ...            ...          ...            ...
# 94  63.0  Female             No           3.47   Bronchitis     Medication
# 95  54.0    Male            Yes           2.03  Lung Cancer            NaN
# 96  84.0    Male             No           4.69  Lung Cancer     Medication
# 97  66.0    Male            Yes           4.50   Bronchitis     Medication
# 98  22.0  Female             No           2.23         COPD        Surgery
#
#     Hospital Visits Recovered
# 0              14.0       Yes
# ...

# %%
data["Age"].fillna(data["Age"].mean(), inplace=True)
data["Lung Capacity"].fillna(data["Lung Capacity"].mean(), inplace=True)
data["Hospital Visits"].fillna(data["Hospital Visits"].mean(), inplace=True)
data.fillna(method='bfill', inplace=True)
data
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16800\4291507442.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Age"].fillna(data["Age"].mean(), inplace=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_16800\4291507442.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
data.isna().sum()
# Out:
# Age                0
# Gender             0
# Smoking Status     0
# Lung Capacity      0
# Disease Type       0
# Treatment Type     0
# Hospital Visits    0
# Recovered          0
# dtype: int64

# %%
data.mode()
# Out:
#     Age Gender Smoking Status  Lung Capacity Disease Type Treatment Type  \
# 0  81.0   Male            Yes       3.357684    Pneumonia     Medication
#
#    Hospital Visits Recovered
# 0              7.0       Yes

# %%
Q1=data["Hospital Visits"].quantile(0.25)
Q2=data["Hospital Visits"].quantile(0.50)
Q3=data["Hospital Visits"].quantile(0.75)
IQR=Q3-Q1
IQR
# Out:
# np.float64(6.0)

# %%
lowerlimit= Q1-1.5*IQR
upperlimit= Q3+1.5*IQR
lowerlimit,upperlimit
# Out:
# (np.float64(-4.0), np.float64(20.0))

# %%
data_between = data[data["Hospital Visits"].between(lowerlimit, upperlimit, inclusive='left')]
data_between
# Out:
#      Age  Gender Smoking Status  Lung Capacity Disease Type Treatment Type  \
# 0   71.0  Female             No       4.490000         COPD        Therapy
# 1   34.0  Female            Yes       3.357684   Bronchitis        Surgery
# 2   80.0    Male            Yes       1.950000         COPD     Medication
# 3   40.0  Female            Yes       3.357684   Bronchitis     Medication
# 4   43.0    Male            Yes       4.600000         COPD        Surgery
# ..   ...     ...            ...            ...          ...            ...
# 94  63.0  Female             No       3.470000   Bronchitis     Medication
# 95  54.0    Male            Yes       2.030000  Lung Cancer     Medication
# 96  84.0    Male             No       4.690000  Lung Cancer     Medication
# 97  66.0    Male            Yes       4.500000   Bronchitis     Medication
# 98  22.0  Female             No       2.230000         COPD        Surgery
#
#     Hospital Visits Recovered
# 0         14.000000       Yes
# ...

# %%
data_no_outliers = data[data["Hospital Visits"].between(lowerlimit, upperlimit, inclusive='neither')]
data_no_outliers
# Out:
#      Age  Gender Smoking Status  Lung Capacity Disease Type Treatment Type  \
# 0   71.0  Female             No       4.490000         COPD        Therapy
# 1   34.0  Female            Yes       3.357684   Bronchitis        Surgery
# 2   80.0    Male            Yes       1.950000         COPD     Medication
# 3   40.0  Female            Yes       3.357684   Bronchitis     Medication
# 4   43.0    Male            Yes       4.600000         COPD        Surgery
# ..   ...     ...            ...            ...          ...            ...
# 94  63.0  Female             No       3.470000   Bronchitis     Medication
# 95  54.0    Male            Yes       2.030000  Lung Cancer     Medication
# 96  84.0    Male             No       4.690000  Lung Cancer     Medication
# 97  66.0    Male            Yes       4.500000   Bronchitis     Medication
# 98  22.0  Female             No       2.230000         COPD        Surgery
#
#     Hospital Visits Recovered
# 0         14.000000       Yes
# ...

# %%
import matplotlib.pyplot as plt

plt.hist(data["Hospital Visits"], bins=15, color='blue', edgecolor='black')
plt.xlabel("Hospital Visits")
plt.ylabel("Frequency")
plt.title("Hospital Visits Histogram")
plt.show()

# %%
plt.scatter(data["Hospital Visits"], data["Age"])
plt.ylabel("Days")
plt.xlabel("Hospital Visits")
plt.title("Hospital Visits vs Age")
plt.show()

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Smoking Status', 'Lung Capacity', 'Disease Type',
#        'Treatment Type', 'Hospital Visits', 'Recovered'],
#       dtype='object')

# %%
cleanedData = data.drop(columns=["Gender", "Smoking Status", "Disease Type","Recovered","Treatment Type"])
cleanedData
# Out:
#      Age  Lung Capacity  Hospital Visits
# 0   71.0       4.490000        14.000000
# 1   34.0       3.357684         7.000000
# 2   80.0       1.950000         4.000000
# 3   40.0       3.357684         1.000000
# 4   43.0       4.600000         7.755319
# ..   ...            ...              ...
# 94  63.0       3.470000        13.000000
# 95  54.0       2.030000        11.000000
# 96  84.0       4.690000         6.000000
# 97  66.0       4.500000        13.000000
# 98  22.0       2.230000         9.000000
#
# [99 rows x 3 columns]

# %%
cleanedData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              99 non-null     float64
#  1   Lung Capacity    99 non-null     float64
#  2   Hospital Visits  99 non-null     float64
# dtypes: float64(3)
# memory usage: 2.4 KB

# %%
correlatedData = cleanedData.corr()
correlatedData
# Out:
#                       Age  Lung Capacity  Hospital Visits
# Age              1.000000       0.031799        -0.098470
# Lung Capacity    0.031799       1.000000        -0.025157
# Hospital Visits -0.098470      -0.025157         1.000000

# %%
import seaborn as sns
plt.figure(figsize=(9, 7))
sns.heatmap(correlatedData, annot=True, linewidths=1)
plt.title("Correlated Data Heatmap")
plt.show()
